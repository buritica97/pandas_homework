# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_returns_data = pd.read_csv(whale_returns_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
whale_returns_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_data = whale_returns_data.dropna().copy()
whale_returns_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
#Checking number of nulls again 
whale_returns_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_returns_data = pd.read_csv(algo_returns_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
algo_returns_data.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_returns_data = algo_returns_data.dropna().copy()
algo_returns_data.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
#Checking number of nulls again 
algo_returns_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")
sp500_history_data = pd.read_csv(sp500_history_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
sp500_history_data.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Sort datetime index in ascending order (past to present)
sp500_history_data.sort_index(inplace = True)
sp500_history_data.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Clean identified numeric fields with $ symbol
sp500_history_data["Close"] = sp500_history_data["Close"].str.replace("$", "")
sp500_history_data["Close"]
# Out:
# Date
# 2012-10-01    1444.49
# 2012-10-02    1445.75
# 2012-10-03    1450.99
# 2012-10-04    1461.40
# 2012-10-05    1460.93
#                ...
# 2019-04-16    2907.06
# 2019-04-17    2900.45
# 2019-04-18    2905.03
# 2019-04-22    2907.97
# 2019-04-23    2933.68
# Name: Close, Length: 1649, dtype: object

# %%
# Check Data Types
sp500_history_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history_data["Close"] = sp500_history_data["Close"].astype("float")

# %%
# Confirm conversion worked as expected
sp500_history_data.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_history_data.pct_change()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_daily_returns = sp500_daily_returns.dropna()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename Column
sp500_daily_returns = sp500_daily_returns.rename(columns={'Close': 'S&P 500'})
sp500_daily_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
joined_portfolios = pd.concat([whale_returns_data, algo_returns_data, sp500_daily_returns], axis="columns", join="inner")
joined_portfolios.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
joined_portfolios.plot(figsize=(10,5), title=('Daily Returns'))
# Out:
# <AxesSubplot:title={'center':'Daily Returns'}, xlabel='Date'>

# %%
# Calculate the cumulative returns using the 'cumprod()' function
cumulative_returns = (1 + joined_portfolios).cumprod()
cumulative_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                   0.998734            0.995019
# 2015-03-04                   1.000962            0.998245
# 2015-03-05                   1.004981            1.002314
# 2015-03-06                   0.997037            0.998731
# 2015-03-09                   0.997617            1.002951
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                     0.999504                0.993431  0.998058
# 2015-03-04                     0.996972                0.997617  0.989486
# 2015-03-05                     0.999319                1.004327  0.988541
# 2015-03-06                     0.990844                0.991172  0.983641
# 2015-03-09                     0.996633                0.989534  0.978283
#
#               Algo 2   S&P 500
# Date
# 2015-03-03  0.999051  0.995461
# 2015-03-04  1.001464  0.991093
# 2015-03-05  1.005794  0.992278
# ...

# %%
# Plot cumulative returns
cumulative_returns.plot(figsize=(10,5), title=('Cumulative Returns'))
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns'}, xlabel='Date'>

# %%
cumulative_returns.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   1.160965            0.786811
# 2019-04-17                   1.157602            0.781723
# 2019-04-18                   1.159278            0.782678
# 2019-04-22                   1.156280            0.776939
# 2019-04-23                   1.164568            0.779646
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                     0.862080                1.526861  1.944990
# 2019-04-17                     0.858279                1.531781  1.924954
# 2019-04-18                     0.858778                1.534716  1.923823
# 2019-04-22                     0.855652                1.533046  1.925124
# 2019-04-23                     0.861189                1.553401  1.934691
#
#               Algo 2   S&P 500
# Date
# 2019-04-16  1.267768  1.372945
# 2019-04-17  1.261140  1.369823
# 2019-04-18  1.259590  1.371986
# ...

# %% [markdown]
# ### Question: Does any portfolio outperform the S&P 500?
#
# Based on the final data point on the Cumulative Returns plot above, we can determine that, the Algo 1 portfolio and the Berkshire Hathaway Inc portfolios seem to outperform the S&P 500.

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
joined_portfolios.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
daily_std = joined_portfolios.std()
daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500                        0.008554
# dtype: float64

# %%
# Daily Standard Deviations
# Step #1: Which portfolios are riskier than the S&P 500? 
daily_std = pd.DataFrame(daily_std)
daily_std
# Out:
#                                     0
# SOROS FUND MANAGEMENT LLC    0.007895
# PAULSON & CO.INC.            0.007023
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919
# Algo 1                       0.007620
# Algo 2                       0.008342
# S&P 500                      0.008554

# %%
# Daily Standard Deviations
# Step #2: Which portfolios are riskier than the S&P 500? 
daily_std = daily_std.rename(columns = {0:"std"})
daily_std
# Out:
#                                   std
# SOROS FUND MANAGEMENT LLC    0.007895
# PAULSON & CO.INC.            0.007023
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919
# Algo 1                       0.007620
# Algo 2                       0.008342
# S&P 500                      0.008554

# %%
# Daily Standard Deviations
# Step #3: Which portfolios are riskier than the S&P 500? 
higher_std = daily_std[daily_std['std']>daily_std.loc['S&P 500', 'std']]
higher_std
# Out:
#                                   std
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std
# Out:
#                                   std
# SOROS FUND MANAGEMENT LLC    0.125335
# PAULSON & CO.INC.            0.111488
# TIGER GLOBAL MANAGEMENT LLC  0.172936
# BERKSHIRE HATHAWAY INC       0.205077
# Algo 1                       0.120967
# Algo 2                       0.132430
# S&P 500                      0.135786

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
STD21 = joined_portfolios.rolling(window = 21).std().plot(figsize = (20,10))

# %%
# Construct a correlation table
correlation = joined_portfolios.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# S&P 500                                       0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
# Beta (Step 1: Calculate Covariance)
BH_rolling_covariance = joined_portfolios['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(joined_portfolios['S&P 500'])
BH_rolling_covariance
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.000055
# 2019-04-17    0.000049
# 2019-04-18    0.000049
# 2019-04-22    0.000049
# 2019-04-23    0.000048
# Length: 1043, dtype: float64

# %%
# Beta (Step 2: Calculate Variance)
rolling_variance = joined_portfolios['S&P 500'].rolling(window=60).var()
rolling_variance
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    0.000041
# 2019-04-17    0.000037
# 2019-04-18    0.000037
# 2019-04-22    0.000037
# 2019-04-23    0.000037
# Name: S&P 500, Length: 1043, dtype: float64

# %%
# Beta (Step 3: Calculate Beta for a single portfolio compared to the total market (S&P 500))
#(Your graph may differ, dependent upon which portfolio you are comparing)
BH_beta = BH_rolling_covariance/rolling_variance 
BH_beta
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-16    1.337986
# 2019-04-17    1.301791
# 2019-04-18    1.302226
# 2019-04-22    1.304125
# 2019-04-23    1.278284
# Length: 1043, dtype: float64

# %%
#Beta (Step 4: Plot Rolling Beta)
BH_beta.plot(figsize = (20,10), title="BERKSHIRE HATHAWAY INC Beta")
# Out:
# <AxesSubplot:title={'center':'BERKSHIRE HATHAWAY INC Beta'}, xlabel='Date'>

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
ewm = joined_portfolios.ewm(halflife = 21).std()
ewm.plot(figsize = (20,10), title="Exponentially Weighted Average")
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Average'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
sharpe_ratios = (joined_portfolios.mean()*252)/(joined_portfolios.std()*np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500                        0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ## On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales?
# ### Type your answer here:
#
# The algo 1 portfolio seems to outprefrom both the market (S&P 500) and the whales. The algo 2 portfolio seems to outpreform all of the whales expect for Berkshire Hathaway Inc. The algo 2 does not seem to outpreform the S&P 500.

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock 
mtb_returns_csv = Path("Resources/mtb_historical.csv")
mtb_returns_data = pd.read_csv(mtb_returns_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
mtb_returns_data.head()
# Out:
#            Symbol   Close
# Date
# 2018-05-18    MTB  181.83
# 2018-05-21    MTB  182.05
# 2018-05-22    MTB  183.89
# 2018-05-23    MTB  180.76
# 2018-05-24    MTB  179.89

# %%
# Read the second stock
dis_returns_csv = Path("Resources/dis_historical.csv")
dis_returns_data = pd.read_csv(dis_returns_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
dis_returns_data.head()
# Out:
#            Symbol   Close
# Date
# 2018-05-18    DIS  103.93
# 2018-05-21    DIS  104.06
# 2018-05-22    DIS  104.07
# 2018-05-23    DIS  102.89
# 2018-05-24    DIS  102.11

# %%
# Read the third stock
nflx_returns_csv = Path("Resources/nflx_historical.csv")
nflx_returns_data = pd.read_csv(nflx_returns_csv, index_col='Date', parse_dates=True, infer_datetime_format=True)
nflx_returns_data.head()
# Out:
#            Symbol   Close
# Date
# 2018-05-18   NFLX  324.18
# 2018-05-21   NFLX  331.82
# 2018-05-22   NFLX  331.62
# 2018-05-23   NFLX  344.72
# 2018-05-24   NFLX  349.29

# %%
# Concatenate all stocks into a single DataFrame
joined_portfolios_2 = pd.concat([mtb_returns_data, dis_returns_data, nflx_returns_data], axis="rows", join="inner")
joined_portfolios_2.head()
# Out:
#            Symbol   Close
# Date
# 2018-05-18    MTB  181.83
# 2018-05-21    MTB  182.05
# 2018-05-22    MTB  183.89
# 2018-05-23    MTB  180.76
# 2018-05-24    MTB  179.89

# %%
# Reset the index
joined_portfolios_2 = joined_portfolios_2.reset_index()
joined_portfolios_2.head()
# Out:
#         Date Symbol   Close
# 0 2018-05-18    MTB  181.83
# 1 2018-05-21    MTB  182.05
# 2 2018-05-22    MTB  183.89
# 3 2018-05-23    MTB  180.76
# 4 2018-05-24    MTB  179.89

# %%
# Pivot so that each column of prices represents a unique symbol
joined_portfolios_2 = joined_portfolios_2.pivot(index="Date", columns="Symbol", values="Close")
joined_portfolios_2.head()
# Out:
# Symbol         DIS     MTB    NFLX
# Date
# 2018-05-18  103.93  181.83  324.18
# 2018-05-21  104.06  182.05  331.82
# 2018-05-22  104.07  183.89  331.62
# 2018-05-23  102.89  180.76  344.72
# 2018-05-24  102.11  179.89  349.29

# %%
# Calculate Daily Returns
my_portfolio_returns = joined_portfolios_2.pct_change()
my_portfolio_returns.head()
# Out:
# Symbol           DIS       MTB      NFLX
# Date
# 2018-05-18       NaN       NaN       NaN
# 2018-05-21  0.001251  0.001210  0.023567
# 2018-05-22  0.000096  0.010107 -0.000603
# 2018-05-23 -0.011339 -0.017021  0.039503
# 2018-05-24 -0.007581 -0.004813  0.013257

# %%
# Count nulls
my_portfolio_returns.isnull().sum()
# Out:
# Symbol
# DIS     1
# MTB     1
# NFLX    1
# dtype: int64

# %%
# Drop nulls
my_portfolio_returns= my_portfolio_returns.dropna().copy()
my_portfolio_returns.head()
# Out:
# Symbol           DIS       MTB      NFLX
# Date
# 2018-05-21  0.001251  0.001210  0.023567
# 2018-05-22  0.000096  0.010107 -0.000603
# 2018-05-23 -0.011339 -0.017021  0.039503
# 2018-05-24 -0.007581 -0.004813  0.013257
# 2018-05-25  0.000881 -0.004503  0.005726

# %%
#Checking number of nulls again 
my_portfolio_returns.isnull().sum()
# Out:
# Symbol
# DIS     0
# MTB     0
# NFLX    0
# dtype: int64

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
weighted_portfolio_returns = my_portfolio_returns.dot(weights)
weighted_portfolio_returns.dropna().head()
# Out:
# Date
# 2018-05-21    0.008676
# 2018-05-22    0.003200
# 2018-05-23    0.003714
# 2018-05-24    0.000288
# 2018-05-25    0.000702
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
final_portfolio = pd.concat([joined_portfolios, weighted_portfolio_returns], axis="columns", join="inner")

# %%
# Rename Column
final_portfolio = final_portfolio.rename(columns={0:'Custom'})
final_portfolio.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-05-21                   0.002503           -0.001195
# 2018-05-22                  -0.002345            0.001168
# 2018-05-23                  -0.000899           -0.000659
# 2018-05-24                  -0.002160           -0.002229
# 2018-05-25                   0.002146            0.002160
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-05-21                    -0.001153                0.010370 -0.003092
# 2018-05-22                    -0.000240               -0.002455  0.011234
# 2018-05-23                     0.005062                0.011108 -0.002093
# 2018-05-24                     0.000880                0.002245  0.001075
# 2018-05-25                     0.008299               -0.000916 -0.001142
#
#               Algo 2   S&P 500    Custom
# Date
# 2018-05-21  0.004924  0.007387  0.008676
# 2018-05-22 -0.005628 -0.003136  0.003200
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
final_portfolio.dropna().head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2018-05-21                   0.002503           -0.001195
# 2018-05-22                  -0.002345            0.001168
# 2018-05-23                  -0.000899           -0.000659
# 2018-05-24                  -0.002160           -0.002229
# 2018-05-25                   0.002146            0.002160
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2018-05-21                    -0.001153                0.010370 -0.003092
# 2018-05-22                    -0.000240               -0.002455  0.011234
# 2018-05-23                     0.005062                0.011108 -0.002093
# 2018-05-24                     0.000880                0.002245  0.001075
# 2018-05-25                     0.008299               -0.000916 -0.001142
#
#               Algo 2   S&P 500    Custom
# Date
# 2018-05-21  0.004924  0.007387  0.008676
# 2018-05-22 -0.005628 -0.003136  0.003200
# ...

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
# Calculate the standard deviation for each portfolio. 
final_daily_std = final_portfolio.std()
final_daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.009317
# PAULSON & CO.INC.              0.007417
# TIGER GLOBAL MANAGEMENT LLC    0.014774
# BERKSHIRE HATHAWAY INC         0.015700
# Algo 1                         0.008492
# Algo 2                         0.008874
# S&P 500                        0.009665
# Custom                         0.013783
# dtype: float64

# %%
# Risk
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std
# Out:
#                                   std
# SOROS FUND MANAGEMENT LLC    0.125335
# PAULSON & CO.INC.            0.111488
# TIGER GLOBAL MANAGEMENT LLC  0.172936
# BERKSHIRE HATHAWAY INC       0.205077
# Algo 1                       0.120967
# Algo 2                       0.132430
# S&P 500                      0.135786

# %%
# Rolling
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
std_dev_21 = final_portfolio.rolling(window = 21).std().plot(figsize = (20,10), title = "21 Day Rolling Standard Deviation")

# %%
# Annualized Sharpe Ratios
final_sharpe_ratios = (final_portfolio.mean()*252)/(final_portfolio.std()*np.sqrt(252))
final_sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.424626
# PAULSON & CO.INC.              0.218810
# TIGER GLOBAL MANAGEMENT LLC   -0.969653
# BERKSHIRE HATHAWAY INC         0.238758
# Algo 1                         2.118468
# Algo 2                         0.031107
# S&P 500                        0.630241
# Custom                         0.769167
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
final_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
# Create a correlation analysis
final_correlation = final_portfolio.corr()
final_correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791767
# PAULSON & CO.INC.                             0.791767            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.476974            0.484958
# BERKSHIRE HATHAWAY INC                        0.818471            0.652127
# Algo 1                                        0.340344            0.365796
# Algo 2                                        0.864577            0.783617
# S&P 500                                       0.878049            0.767300
# Custom                                        0.770229            0.656922
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.476974
# PAULSON & CO.INC.                               0.484958
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.324751
# ...

# %%
# Beta (Step 1: Calculate Covariance)
CP_rolling_covariance = final_portfolio['Custom'].rolling(window=21).cov(final_portfolio['S&P 500'])
CP_rolling_covariance
# Out:
# Date
# 2018-05-21         NaN
# 2018-05-22         NaN
# 2018-05-23         NaN
# 2018-05-24         NaN
# 2018-05-25         NaN
#                 ...
# 2019-04-16    0.000051
# 2019-04-17    0.000050
# 2019-04-18    0.000049
# 2019-04-22    0.000055
# 2019-04-23    0.000021
# Length: 232, dtype: float64

# %%
# Beta (Step 2: Calculate Variance)
rolling_variance = final_portfolio['S&P 500'].rolling(window=21).var()
rolling_variance
# Out:
# Date
# 2018-05-21         NaN
# 2018-05-22         NaN
# 2018-05-23         NaN
# 2018-05-24         NaN
# 2018-05-25         NaN
#                 ...
# 2019-04-16    0.000042
# 2019-04-17    0.000043
# 2019-04-18    0.000042
# 2019-04-22    0.000037
# 2019-04-23    0.000019
# Name: S&P 500, Length: 232, dtype: float64

# %%
# Beta (Step 3: Calculate Beta for your custom portfolio compared to the total market (S&P 500))
CP_beta = CP_rolling_covariance/rolling_variance 
CP_beta
# Out:
# Date
# 2018-05-21         NaN
# 2018-05-22         NaN
# 2018-05-23         NaN
# 2018-05-24         NaN
# 2018-05-25         NaN
#                 ...
# 2019-04-16    1.210734
# 2019-04-17    1.167488
# 2019-04-18    1.181023
# 2019-04-22    1.487491
# 2019-04-23    1.148874
# Length: 232, dtype: float64

# %%
#Beta (Step 4: Plot Rolling Beta)
CP_beta.plot(figsize = (20,10), title="Custom Portfolio Beta")
# Out:
# <AxesSubplot:title={'center':'Custom Portfolio Beta'}, xlabel='Date'>
